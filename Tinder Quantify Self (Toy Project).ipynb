# %% [markdown]
# ## Tinder Quantify Self Toy Project
# ### 1. explore data analysis (EDA)
# - 세울 수 있는 가설들
# - my definition of 티키타카?
# - 어떤 대화를 해야 오래 지속이 될까?
# - 한번에 몇번의 conversation을 할까?
# - 첫주제가 영향을 주나?
#
# ### 2. leading to conclusion

# %% [markdown]
# json 파일 읽어오기

# %% [markdown]
# - https://zeddios.tistory.com/90
# - https://velog.io/@lzhxxn/JSON-Parsing%ED%8C%8C%EC%8B%B1%EC%9D%B4%EB%9E%80

# %% [markdown]
# json(java script object notation) - 일종의 데이터 형식이라는 것 정도

# %%
import json

# %%
data = '[{"Campaigns":{"current_campaigns":[],"expired_campaigns":[]},"Experiences":{},"Messages":[{"match_id":"Match 11","messages":[{"to":10,"from":"You","message":"안녕하세용~!!","sent_date":"Tue, 10 Aug 2021 09:34:58 GMT"},{"to":10,"from":"You","message":"네ㅋㅋ운동도 막끝나서 집가구 있어요","sent_date":"Tue, 10 Aug 2021 11:28:26 GMT"},{"to":10,"from":"You","message":"ㅋㅋㅋ재택근무가 장기화되버려서ㅠ 생활습관 바꿀겸 피티 시작해버렸어요","sent_date":"Tue, 10 Aug 2021 12:01:06 GMT"},{"to":10,"from":"You","message":"오늘 막 바프 스튜디오도 예약해서 간만에 두근두근해요ㅋㅋㅋ","sent_date":"Tue, 10 Aug 2021 12:02:03 GMT"},{"to":10,"from":"You","message":"앜ㅋㅋㅋㅋㅋㅋㅋ","sent_date":"Tue, 10 Aug 2021 12:04:08 GMT"},{"to":10,"from":"You","message":"지금도 체지방만 걷어내면 찍을 수는 있다지만","sent_date":"Tue, 10 Aug 2021 12:05:09 GMT"},{"to":10,"from":"You","message":"11월 말로 잡았으니 조금 욕심내려구용ㅎㅎ","sent_date":"Tue, 10 Aug 2021 12:05:26 GMT"},{"to":10,"from":"You","message":"완전 맞아요....","sent_date":"Tue, 10 Aug 2021 12:05:44 GMT"},{"to":10,"from":"You","message":"전에는 몰입도 높힌다고 방에서 향수뿌리고 업무했는데","sent_date":"Tue, 10 Aug 2021 12:06:24 GMT"},{"to":10,"from":"You","message":"요즘은 그냥 뭐,, 출근10분전에 일어나서 업무시작해요ㅋㅋㄱㅋ","sent_date":"Tue, 10 Aug 2021 12:06:53 GMT"},{"to":10,"from":"You","message":"지금 찍으면 복근은 없을테지만ㅋㅋㅋ","sent_date":"Tue, 10 Aug 2021 12:20:03 GMT"},{"to":10,"from":"You","message":"예약금 넣으니까 뭔가 땅하고 디데이 설정된 느낌이어서 그런가봐요","sent_date":"Tue, 10 Aug 2021 12:20:40 GMT"},{"to":10,"from":"You","message":"아 hr이면 업무특성상","sent_date":"Tue, 10 Aug 2021 12:20:56 GMT"},{"to":10,"from":"You","message":"사무실 출근이 필수적인가요??ㅠ","sent_date":"Tue, 10 Aug 2021 12:21:16 GMT"},{"to":10,"from":"You","message":"글쿤용,,","sent_date":"Tue, 10 Aug 2021 13:35:19 GMT"},{"to":10,"from":"You","message":"아, 질문! ","sent_date":"Tue, 
"c62a7aab-18fc-4141-ab08-db471724844f","2021-08-19":"","2021-08-21":"c62a7aab-18fc-4141-ab08-db471724844f","2021-08-22":"c62a7aab-18fc-4141-ab08-db471724844f","2021-08-24":"c62a7aab-18fc-4141-ab08-db471724844f","2021-08-26":"c62a7aab-18fc-4141-ab08-db471724844f","2021-08-30":"c62a7aab-18fc-4141-ab08-db471724844f","2021-09-11":"","2021-09-23":"c62a7aab-18fc-4141-ab08-db471724844f","2021-11-02":"c62a7aab-18fc-4141-ab08-db471724844f"},"idfa":{"2021-05-13":"","2021-05-14":"","2021-05-15":"","2021-05-16":"","2021-05-17":"","2021-05-18":"","2021-05-19":"","2021-05-20":"","2021-05-21":"","2021-05-22":"","2021-05-23":"","2021-05-24":"","2021-05-25":"","2021-05-27":"","2021-05-30":"","2021-06-05":"","2021-06-09":"","2021-06-14":"","2021-07-11":"","2021-07-17":"","2021-07-25":"","2021-07-26":"","2021-07-27":"","2021-07-28":"","2021-07-29":"","2021-07-30":"","2021-07-31":"","2021-08-01":"","2021-08-03":"","2021-08-09":"","2021-08-10":"","2021-08-11":"","2021-08-12":"","2021-08-13":"","2021-08-14":"","2021-08-15":"","2021-08-16":"","2021-08-18":"","2021-08-19":"","2021-08-21":"","2021-08-22":"","2021-08-24":"","2021-08-26":"","2021-08-30":"","2021-09-11":"","2021-09-23":"","2021-11-02":""}},"User":{"active_time":"2021-11-02T10:06:05.852Z","age_filter_max":35,"age_filter_min":26,"bio":"하이~ &colon;&rpar;\n\nENTP-ESTJ 왔다갔다해요 &lpar;변동은 업무 특성상이 원인인듯&rpar; &sol; 새로운걸 배우거나 경험하는거 좋아해요. 인생모토는 Momento Mori &lpar;하지만 사실상은 겁 많음ㅎ&rpar;\n\n일은 데이터분석, 2년차!!\n\n최근에 가벼운 웨이트 시작해서 술은 못먹지만ㅠ 티키타카 잘 맞으면 커피한잔해요!☕\n\n백신은 1차접종까지 완료&colon;&rpar;\n\nDont mind talking in en but prefer kr\n\n","birth_date":"1996-03-16T00:00:00.000Z","create_date":"2021-05-13T15:06:40.128Z","email":"yololife.sy@gmail.com","full_name":"","gender":"F","gender_filter":"M","interested_in":"M","ip_address":"61.82.87.142","jobs":[{"title":{"displayed":true,"name":"데이터분석 직딩"}}],"name":"Celine","pos":{"at":"Tue, 10 Aug 2021 11:59:36 GMT","lat":37.493092,"lon":127.0563282},"client_registration_info":{"platform":"android","app_version":4251},"phone_id":"821065805464","user_interests":["Trying New Things","Dancing","ENTP","Exhibition","Nature"],"education":"Has no high school or college education","college":[]},"Photos":["0.jpeg","1.jpeg","2.jpeg","3.jpeg","4.jpeg","5.jpeg","6.jpeg","7.jpeg","8.jpeg","9","10"]}]'

# %%
with open('data.json', encoding='UTF8') as f:
    data=json.load(f) #python  JSON to dict

# %%
print(data)
# Out:
# {'Campaigns': {'current_campaigns': [], 'expired_campaigns': []}, 'Experiences': {}, 'Messages': [{'match_id': 'Match 11', 'messages': [{'to': 10, 'from': 'You', 'message': '안녕하세용~!!', 'sent_date': 'Tue, 10 Aug 2021 09:34:58 GMT'}, {'to': 10, 'from': 'You', 'message': '네ㅋㅋ운동도 막끝나서 집가구 있어요', 'sent_date': 'Tue, 10 Aug 2021 11:28:26 GMT'}, {'to': 10, 'from': 'You', 'message': 'ㅋㅋㅋ재택근무가 장기화되버려서ㅠ 생활습관 바꿀겸 피티 시작해버렸어요', 'sent_date': 'Tue, 10 Aug 2021 12:01:06 GMT'}, {'to': 10, 'from': 'You', 'message': '오늘 막 바프 스튜디오도 예약해서 간만에 두근두근해요ㅋㅋㅋ', 'sent_date': 'Tue, 10 Aug 2021 12:02:03 GMT'}, {'to': 10, 'from': 'You', 'message': '앜ㅋㅋㅋㅋㅋㅋㅋ', 'sent_date': 'Tue, 10 Aug 2021 12:04:08 GMT'}, {'to': 10, 'from': 'You', 'message': '지금도 체지방만 걷어내면 찍을 수는 있다지만', 'sent_date': 'Tue, 10 Aug 2021 12:05:09 GMT'}, {'to': 10, 'from': 'You', 'message': '11월 말로 잡았으니 조금 욕심내려구용ㅎㅎ', 'sent_date': 'Tue, 10 Aug 2021 12:05:26 GMT'}, {'to': 10, 'from': 'You', 'message': '완전 맞아요....', 'sent_date': 'Tue, 10 Aug 2021 12:05:44 GMT'
# ...

# %%
print(json.dumps(data, indent='\t',ensure_ascii = False )) #json 가독성 높히기
# Out:
# {
# 	"Campaigns": {
# 		"current_campaigns": [],
# 		"expired_campaigns": []
# 	},
# 	"Experiences": {},
# 	"Messages": [
# 		{
# 			"match_id": "Match 11",
# 			"messages": [
# 				{
# 					"to": 10,
# 					"from": "You",
# 					"message": "안녕하세용~!!",
# 					"sent_date": "Tue, 10 Aug 2021 09:34:58 GMT"
# 				},
# 				{
# 					"to": 10,
# 					"from": "You",
# 					"message": "네ㅋㅋ운동도 막끝나서 집가구 있어요",
# 					"sent_date": "Tue, 10 Aug 2021 11:28:26 GMT"
# 				},
# 				{
# 					"to": 10,
# 					"from": "You",
# 					"message": "ㅋㅋㅋ재택근무가 장기화되버려서ㅠ 생활습관 바꿀겸 피티 시작해버렸어요",
# 					"sent_date": "Tue, 10 Aug 2021 12:01:06 GMT"
# 				},
# 				{
# 					"to": 10,
# 					"from": "You",
# 					"message": "오늘 막 바프 스튜디오도 예약해서 간만에 두근두근해요ㅋㅋㅋ",
# 					"sent_date": "Tue, 10 Aug 2021 12:02:03 GMT"
# 				},
# 				{
# 					"to": 10,
# 					"from": "You",
# 					"message": "앜ㅋㅋㅋㅋㅋㅋㅋ",
# 					"sent_date": "Tue, 10 Aug 2021 12:04:08 GMT"
# 				},
# 				{
# 					"to": 10,
# 					"from": "You",
# ...

# %%
type(data) #자료형 확인
# Out:
# dict

# %%
data['Messages']
# Out:
# [{'match_id': 'Match 11',
#   'messages': [{'to': 10,
#     'from': 'You',
#     'message': '안녕하세용~!!',
#     'sent_date': 'Tue, 10 Aug 2021 09:34:58 GMT'},
#    {'to': 10,
#     'from': 'You',
#     'message': '네ㅋㅋ운동도 막끝나서 집가구 있어요',
#     'sent_date': 'Tue, 10 Aug 2021 11:28:26 GMT'},
#    {'to': 10,
#     'from': 'You',
#     'message': 'ㅋㅋㅋ재택근무가 장기화되버려서ㅠ 생활습관 바꿀겸 피티 시작해버렸어요',
#     'sent_date': 'Tue, 10 Aug 2021 12:01:06 GMT'},
#    {'to': 10,
#     'from': 'You',
#     'message': '오늘 막 바프 스튜디오도 예약해서 간만에 두근두근해요ㅋㅋㅋ',
#     'sent_date': 'Tue, 10 Aug 2021 12:02:03 GMT'},
#    {'to': 10,
#     'from': 'You',
#     'message': '앜ㅋㅋㅋㅋㅋㅋㅋ',
#     'sent_date': 'Tue, 10 Aug 2021 12:04:08 GMT'},
#    {'to': 10,
#     'from': 'You',
#     'message': '지금도 체지방만 걷어내면 찍을 수는 있다지만',
#     'sent_date': 'Tue, 10 Aug 2021 12:05:09 GMT'},
#    {'to': 10,
#     'from': 'You',
#     'message': '11월 말로 잡았으니 조금 욕심내려구용ㅎㅎ',
#     'sent_date': 'Tue, 10 Aug 2021 12:05:26 GMT'},
#    {'to': 10,
# ...

# %%
type(data['Messages'])
# Out:
# list

# %%
len(data['Messages']) #매칭&conversation은 11명
# Out:
# 11

# %% [markdown]
# `data['Messages']`는 매칭후 나눈 대화를 사람별로 `dict`형태로 정리된 형태!

# %%
data['Messages'][1]
# Out:
# {'match_id': 'Match 10',
#  'messages': [{'to': 9,
#    'from': 'You',
#    'message': '아,,, H님 먼저 연락주셔서 감사해욥!!!ㅋㅋㅋ',
#    'sent_date': 'Wed, 11 Aug 2021 06:49:27 GMT'},
#   {'to': 9,
#    'from': 'You',
#    'message': '반갑습니다~!!!',
#    'sent_date': 'Wed, 11 Aug 2021 06:49:35 GMT'},
#   {'to': 9,
#    'from': 'You',
#    'message': '아ㅎㅎ 저도 비슷한 이유로 라이크 했어요!! ',
#    'sent_date': 'Wed, 11 Aug 2021 07:04:03 GMT'},
#   {'to': 9,
#    'from': 'You',
#    'message': '넵! 코로나덕에&lpar;?&rpar; 유효기간 없는 재택근무중이에요ㅋㅋㅋ',
#    'sent_date': 'Wed, 11 Aug 2021 07:04:43 GMT'},
#   {'to': 9,
#    'from': 'You',
#    'message': 'ㅋㅋㅋㅋㅋㅋㅋ',
#    'sent_date': 'Wed, 11 Aug 2021 07:09:52 GMT'},
#   {'to': 9,
#    'from': 'You',
#    'message': '음,, 지금 애드혹이 들어와서',
#    'sent_date': 'Wed, 11 Aug 2021 07:10:03 GMT'},
#   {'to': 9,
#    'from': 'You',
#    'message': '제가 퇴근하고',
#    'sent_date': 'Wed, 11 Aug 2021 07:10:06 GMT'},
#   {'to': 9,
#    'from': 'You',
#    'message': '돌아올게요!!!',
# ...

# %%
type(data['Messages'][1])
# Out:
# dict

# %%
data['Messages'][1]['messages']
# Out:
# [{'to': 9,
#   'from': 'You',
#   'message': '아,,, H님 먼저 연락주셔서 감사해욥!!!ㅋㅋㅋ',
#   'sent_date': 'Wed, 11 Aug 2021 06:49:27 GMT'},
#  {'to': 9,
#   'from': 'You',
#   'message': '반갑습니다~!!!',
#   'sent_date': 'Wed, 11 Aug 2021 06:49:35 GMT'},
#  {'to': 9,
#   'from': 'You',
#   'message': '아ㅎㅎ 저도 비슷한 이유로 라이크 했어요!! ',
#   'sent_date': 'Wed, 11 Aug 2021 07:04:03 GMT'},
#  {'to': 9,
#   'from': 'You',
#   'message': '넵! 코로나덕에&lpar;?&rpar; 유효기간 없는 재택근무중이에요ㅋㅋㅋ',
#   'sent_date': 'Wed, 11 Aug 2021 07:04:43 GMT'},
#  {'to': 9,
#   'from': 'You',
#   'message': 'ㅋㅋㅋㅋㅋㅋㅋ',
#   'sent_date': 'Wed, 11 Aug 2021 07:09:52 GMT'},
#  {'to': 9,
#   'from': 'You',
#   'message': '음,, 지금 애드혹이 들어와서',
#   'sent_date': 'Wed, 11 Aug 2021 07:10:03 GMT'},
#  {'to': 9,
#   'from': 'You',
#   'message': '제가 퇴근하고',
#   'sent_date': 'Wed, 11 Aug 2021 07:10:06 GMT'},
#  {'to': 9,
#   'from': 'You',
#   'message': '돌아올게요!!!',
#   'sent_date': 'Wed, 11 Aug 2021 07:10:09 GMT'},
#  {'to': 9,
#   'from': 'You',
# ...

# %%
import pandas as pd

# %% [markdown]
# Match별로 데이터프레임화하기

# %% [markdown]
# 동적변수 생성
# - https://velog.io/@datata29/%EB%8F%99%EC%A0%81%EC%9C%BC%EB%A1%9C-%EB%B3%80%EC%88%98-%EC%83%9D%EC%84%B1%ED%95%98%EA%B8%B0-for-%EB%AC%B8%EC%9D%84-%EC%9D%B4%EC%9A%A9%ED%95%98%EC%97%AC-%EB%8D%B0%EC%9D%B4%ED%84%B0%ED%94%84%EB%A0%88%EC%9E%84-%EC%AA%BC%EA%B0%9C%EA%B8%B0

# %%
for i in range(11):
    globals()['df_match{}'.format(10-i)] = pd.DataFrame().from_dict(data['Messages'][i]['messages']) #동적변수 global

# %%
for i in range(11):
    conversation_1st_date = globals()['df_match{}'.format(i)]['sent_date'].min()
    print('df_match{}'.format(i), conversation_1st_date)
# Out:
# df_match0 Sat, 15 May 2021 01:47:46 GMT
# df_match1 Sat, 15 May 2021 00:05:28 GMT
# df_match2 Thu, 20 May 2021 06:56:58 GMT
# df_match3 Fri, 21 May 2021 10:11:26 GMT
# df_match4 Sun, 25 Jul 2021 09:47:45 GMT
# df_match5 Mon, 26 Jul 2021 14:06:00 GMT
# df_match6 Tue, 27 Jul 2021 14:50:32 GMT
# df_match7 Thu, 29 Jul 2021 07:30:38 GMT
# df_match8 Tue, 10 Aug 2021 02:18:52 GMT
# df_match9 Wed, 11 Aug 2021 06:49:27 GMT
# df_match10 Thu, 12 Aug 2021 01:01:49 GMT

# %% [markdown]
# ## my definition of `티키타카`?
# - 어떤 대화를 해야 오래 지속이 될까? 내가 흥미로워 하는 주제는 무엇일까?
# - 한번에 몇번의 conversation을 할까?
# - 첫주제가 영향을 주나?

# %%
df_match0
# Out:
#     to from                                            message  \
# 0    0  You                             앗 방금 스와이프 했는데ㅎㅎ 안녕하세요~
# 1    0  You       늦잠 자고 싶었는데 생각보다 일찍 일어나버렸어요 &lpar;살짝 억울&rpar;
# 2    0  You                                    K님두 한주 고생많으셨습니당
# 3    0  You                                            헉......
# 4    0  You                                야...근을 새벽4시까지 한건가욤?
# 5    0  You                                         정말 고생많으셨네요
# 6    0  You                                                  아
# 7    0  You                               ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 8    0  You                                        새벽4시까지 뭐하지?
# 9    0  You                                                게임?
# 10   0  You                                           아, 대박ㅋㅋㅋ
# 11   0  You             음,, 글쎄요. 이번에 재가입한건데 저번에 했을땐 이야기가 안이어져서
# 12   0  You                                       만난분이 없었어요ㅋㅋㅋ
# 13   0  You                    아, 퇴근후 맥주는 몇분 있었는데 영...재미없었어서;;
# ...

# %% [markdown]
# 전반적인 데이터형태는 `나`의 메세지가 있고 나에게 온 상대방의 메세지는 없다. 내가 보낸 구체적인 메세지와 보낸 날짜에 대한 정보 정도 알 수 있다. 우선 매치후 내가 보낸 메세지 카운트를 확인 해보았다.

# %%
for i in range(11):
    message_cnt = globals()['df_match{}'.format(i)]['message'].count()
    print('df_match{}'.format(i), message_cnt)
# Out:
# df_match0 43
# df_match1 20
# df_match2 1
# df_match3 17
# df_match4 3
# df_match5 23
# df_match6 2
# df_match7 4
# df_match8 14
# df_match9 13
# df_match10 95

# %%
dict_match_cnt = {'df_match0': 43
,'df_match1': 20
,'df_match2': 1
,'df_match3': 17
,'df_match4': 3
,'df_match5': 23
,'df_match6': 2
,'df_match7': 4
,'df_match8': 14
,'df_match9': 13
,'df_match10': 95}

# %%
type([dict_match_cnt])
# Out:
# list

# %%
match_cnt=pd.DataFrame().from_dict([dict_match_cnt])

# %%
match_cnt
# Out:
#    df_match0  df_match1  df_match2  df_match3  df_match4  df_match5  \
# 0         43         20          1         17          3         23
#
#    df_match6  df_match7  df_match8  df_match9  df_match10
# 0          2          4         14         13          95

# %%
match_cnt=pd.DataFrame.from_dict({'df_match0': 43
,'df_match1': 20
,'df_match2': 1
,'df_match3': 17
,'df_match4': 3
,'df_match5': 23
,'df_match6': 2
,'df_match7': 4
,'df_match8': 14
,'df_match9': 13
,'df_match10': 95}, orient='index').rename(columns={0:'cnt'})

# %%
match_cnt
# Out:
#             cnt
# df_match0    43
# df_match1    20
# df_match2     1
# df_match3    17
# df_match4     3
# df_match5    23
# df_match6     2
# df_match7     4
# df_match8    14
# df_match9    13
# df_match10   95

# %% [markdown]
# 눈에 띄는 match10, 무슨 대화를 했길래 저렇게 많은 message가 오갔을까?

# %%
df_match10['sent_date'][0][0:1]
# Out:
# 'T'

# %% [markdown]
# 여기서 진행이 멈췄다. 한글 nlp 잠깐 공부해야할듯
# - 파이썬 기반 한글 형태소 패키지인 KoNLPy 사용 가능할 듯
# - 띄어쓰기와 조사로 다른언어보다 해석하기 어려운 한글

# %% [markdown]
# ## 텍스트 전처리
# - 텍스트 정규화 과정으로 클렌징/토큰화/필터링/stemming/lemmatization 작업을 의미한다
#
# ## 한국어 전처리 패키지
# -

# %%
df_match10
# Out:
#     to from                                message  \
# 0   10  You                               안녕하세용~!!
# 1   10  You                    네ㅋㅋ운동도 막끝나서 집가구 있어요
# 2   10  You  ㅋㅋㅋ재택근무가 장기화되버려서ㅠ 생활습관 바꿀겸 피티 시작해버렸어요
# 3   10  You       오늘 막 바프 스튜디오도 예약해서 간만에 두근두근해요ㅋㅋㅋ
# 4   10  You                               앜ㅋㅋㅋㅋㅋㅋㅋ
# ..  ..  ...                                    ...
# 90  10  You                  틴더 알람을 안켜둬서 약간 번거러워옄ㅋ
# 91  10  You                                     아,
# 92  10  You                                     넵넵
# 93  10  You                          sydream0316!!
# 94  10  You                             아, 느낌표 빼구요
#
#                         sent_date
# 0   Tue, 10 Aug 2021 09:34:58 GMT
# 1   Tue, 10 Aug 2021 11:28:26 GMT
# 2   Tue, 10 Aug 2021 12:01:06 GMT
# 3   Tue, 10 Aug 2021 12:02:03 GMT
# 4   Tue, 10 Aug 2021 12:04:08 GMT
# ..                            ...
# 90  Thu, 12 Aug 2021 01:04:15 GMT
# 91  Thu, 12 Aug 2021 01:04:16 GMT
# ...

# %%
import re

# %%
pattern = '([ㄱ-하-ㅣ]+)'
repl=''

# %%
def clean(text):
    return re.sub(pattern=pattern, repl=repl, string=text)

# %%
df_match10_clean = df_match10['message'].apply(clean)

# %%
for i in range(len(df_match10)):
    print(df_match10_clean[i])
# Out:
# ~!!
#
#  화 활   해
#     해  해
#
#
# 11
#  ....
#   힌  향 했
#   ,, 10  해
#
#
#  hr
#   ??
# ,,
# , !
#   ???
#     한
# ...   , 확히    할  🤔
#
#
# &lpar;,,  tmi&rpar;
#      ???
# 합2
#   해했....
# ,,     !
# 혼  해
#      !
#     2~3
#   화
#       해
#
#  ?
#
#       힘
# ,,   해
#
#
#  ,,  &lpar;,&rpar; &lpar;&sol;&rpar; 한    형
#
#    한   &lpar;&rpar;   혜   했    할
#
#   +
# 후   stop
#
#
# !
#   해
#
#
# https&colon;&sol;&sol;www.youtube.com&sol;watch?v=QUXKibjfEM&t=47s
#
#
#
#
# .....
#
#
# 혹  ???
#  화 &lpar;?&rpar;
# 한
# ,  .
#  학
# ???
#
#  할??
#  !
# !!
#     !
#
#
# ! 1
#
#
# !!
#
#
#
#
#
#
# 해
#
#
#   했?
#
#
#
#
#  혹  할???
#
# ,
#
# sydream0316!!
# ,

# %% [markdown]
# 위의 클렌징은 망한듯,, 다 없어진거 같은데?ㅋㅋㅋ

# %%
pip install konlpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from konlpy.tag import Kkma
f_kka = Kkma()
# Out:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# <ipython-input-29-10c438bc3252> in <module>
#       1 from konlpy.tag import Kkma
# ----> 2 f_kka = Kkma()
#
# C:\ProgramData\Anaconda3\lib\site-packages\konlpy\tag\_kkma.py in __init__(self, jvmpath, max_heap_size)
#      93     def __init__(self, jvmpath=None, max_heap_size=1024):
#      94         if not jpype.isJVMStarted():
# ---> 95             jvm.init_jvm(jvmpath, max_heap_size)
#      96
#      97         kkmaJavaPackage = jpype.JPackage('kr.lucypark.kkma')
#
# C:\ProgramData\Anaconda3\lib\site-packages\konlpy\jvm.py in init_jvm(jvmpath, max_heap_size)
#      65                                 '-Dfile.encoding=UTF8',
#      66                                 '-ea', '-Xmx{}m'.format(max_heap_size),
# ---> 67                                 convertStrings=True)
#      68     else:
# ...

# %%
pip install tweepy==3.10.0
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
